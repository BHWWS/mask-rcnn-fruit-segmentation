# %% [markdown]
# # Import dependencies

# %%
import os 
import sys
import random
import math
import numpy as np
import cv2
import matplotlib.pyplot as plt
import json
import pydicom
from imgaug import augmenters as iaa
from tqdm import tqdm
import pandas as pd 
import glob 
import skimage.draw

# %% [markdown]
# # Download Mask RCNN library

# %%
# !git clone https://www.github.com/matterport/Mask_RCNN.git
# Out:
# Cloning into 'Mask_RCNN'...
# remote: Enumerating objects: 956, done.
# remote: Total 956 (delta 0), reused 0 (delta 0), pack-reused 956
# Receiving objects: 100% (956/956), 111.90 MiB | 54.66 MiB/s, done.
# Resolving deltas: 100% (572/572), done.

# %%
os.chdir('Mask_RCNN')

# %%
ROOT_DIR = '/kaggle/project'

# %% [markdown]
# # Import MaskRCNN dependencies

# %%
sys.path.append(os.path.join(ROOT_DIR, 'Mask_RCNN'))  # To find local version of the library
from mrcnn.config import Config
from mrcnn import utils
import mrcnn.model as modellib
from mrcnn import visualize
from mrcnn.model import log
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Create Configuration class for Detector

# %%
# The following parameters have been selected to reduce running time for demonstration purposes 
# These are not optimal 

class DetectorConfig(Config):
    """Configuration for training pneumonia detection on the RSNA pneumonia dataset.
    Overrides values in the base Config class.
    """
    
    NAME = 'fruits'
    
    GPU_COUNT = 1
    IMAGES_PER_GPU = 8
    
    BACKBONE = 'resnet50'
    
    NUM_CLASSES = 4  # background + 3 fruit classes
    
    IMAGE_MIN_DIM = 256
    IMAGE_MAX_DIM = 256
    RPN_ANCHOR_SCALES = (16, 32, 64, 128, 256)
    TRAIN_ROIS_PER_IMAGE = 32

    STEPS_PER_EPOCH = 25
    
config = DetectorConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet50
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     8
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 8
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  256
# IMAGE_META_SIZE                16
# IMAGE_MIN_DIM                  256
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [256 256   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           fruits
# NUM_CLASSES                    4
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (16, 32, 64, 128, 256)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                25
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           32
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %% [markdown]
# # Extend existing Dataset class to customize methods

# %%
class DetectorDataset(utils.Dataset):
    """Dataset class for training pneumonia detection on the RSNA pneumonia dataset.
    """
    
    def load_labels(self, labels_list):
        for i, label in enumerate(labels_list):
            self.add_class('fruits', i + 1, label)
            
    def load_dataset(self, images_obj):
        for image_obj in images_obj:
            image_id = image_obj['image_id']
            image_path = image_obj['image_path']
            num_ids = image_obj['num_ids']
            polygons = image_obj['polygons']
            width = image_obj['width']
            height = image_obj['height']
            self.add_image("fruits", image_id=image_id, path=image_path,
                           width=width, height=height, polygons=polygons,num_ids=num_ids)
            
    def image_reference(self, image_id):
        info = self.image_info[image_id]
        return info['path']

    def draw_shape(self, image, shape, dims, color):
        """Draws a shape from the given specs."""
        # Get the center x, y and the size s
        x, y, s = dims
        if shape == 'square':
            cv2.rectangle(image, (x-s, y-s), (x+s, y+s), color, -1)
        elif shape == "circle":
            cv2.circle(image, (x, y), s, color, -1)
        elif shape == "triangle":
            points = np.array([[(x, y-s),
                                (x-s/math.sin(math.radians(60)), y+s),
                                (x+s/math.sin(math.radians(60)), y+s),
                                ]], dtype=np.int32)
            cv2.fillPoly(image, points, color)
        return image

    def load_mask(self, image_id):
        """Generate instance masks for an image.
       Returns:
        masks: A bool array of shape [height, width, instance count] with
            one mask per instance.
        class_ids: a 1D array of class IDs of the instance masks.
        """
        info = self.image_info[image_id]
        num_ids = info['num_ids']
        mask = np.zeros([info["height"], info["width"], len(info["polygons"])],
                        dtype=np.uint8)

        for i, p in enumerate(info["polygons"]):
            # Get indexes of pixels inside the polygon and set them to 1
            rr, cc = skimage.draw.polygon(p['all_points_y'], p['all_points_x'])
            mask[rr, cc, i] = 1

        num_ids = np.array(num_ids, dtype=np.int32)
        return mask, num_ids

# %% [markdown]
# # Set root directory for training and test dataset

# %%
train_image_path = os.path.join('../../input', 'train_zip')
test_image_path = os.path.join('../../input', 'test_zip')

# %% [markdown]
# # Convert xml file information to dict

# %% [markdown]
# ## Download xmltodict helper dependencies

# %%
# !pip install xmltodict
# Out:
# Collecting xmltodict
#   Downloading https://files.pythonhosted.org/packages/28/fd/30d5c1d3ac29ce229f6bdc40bbc20b28f716e8b363140c26eff19122d8a5/xmltodict-0.12.0-py2.py3-none-any.whl
# Installing collected packages: xmltodict
# Successfully installed xmltodict-0.12.0

# %% [markdown]
# ## Define labels

# %%
labels = ["apple", "banana", "orange"]

# %% [markdown]
# ## Parse a single annoation
# - Extract the dict object and convert it into cocos format
#
# Example of format:
# {
#     "all_points_x": [...],
#     "all_points_y": [...],
#     "num_id": 3
# }

# %%
def parse_single_annotation(label_obj):
    #print(label_obj)
    name = label_obj['name']
    # Get label
    num_id = labels.index(name) + 1
    bb_box = label_obj['bndbox']
    # Extract the xmin xmax ymin and ymax of bounding box
    xmin = int(bb_box['xmin'])
    xmax = int(bb_box['xmax'])
    ymin = int(bb_box['ymin'])
    ymax = int(bb_box['ymax'])
    # Convert it into polygon format. So we need 5 points for both x and y
    all_points_x = [xmin, xmax, xmax, xmin, xmin]
    all_points_y = [ymin, ymin, ymax, ymax, ymin]
    return all_points_x, all_points_y, num_id

# %% [markdown]
# ## Parse the images and annotations and it in a single array

# %%
import xmltodict
import json
train_images = []
def transform_annotations(image_path):
    # Start the index from 100
    curr_idx = 100
    images_list = []
    # List the files in the training or test path
    for i in os.listdir(os.path.join(image_path)):
        # Get the image path
        img_path = os.path.join(image_path, i)
        split_img_path = i.split('.')
        # check if the file is a .jpg ext. We ignore .xml file as they will be parsed based on .jpg file name
        if split_img_path[1] == 'jpg':
            # Define dict key value pair required in coco dataset
            polygons = []
            num_ids = []
            # Read the image file 
            file_data = cv2.imread(img_path)
            # Get the heigh and width. OpenCV shape is in the format h, w, depth
            height, width, _ = file_data.shape
            # Open the xml file which has the same name of the image we have opened for this iteration
            with open(os.path.join(image_path, split_img_path[0] + '.xml')) as fd:
                # Load the xml -> convert xml to dict -> convert to json
                bb_file = json.loads(json.dumps(xmltodict.parse(fd.read())))
                # There are two case - bb_file['annotation']['object'] can exist as a single dict or as a list of dict.
                # Thus, we need to do a check to see whether it is a list or not.
                # If the value is a data type of list:
                if isinstance(bb_file['annotation']['object'], list):
                    # Loop through each dict in the list
                    for obj in bb_file['annotation']['object']:
                        # Parse each annotation individually
                        all_points_x, all_points_y, num_id = parse_single_annotation(obj)
                        # Append the points into polygon list
                        polygons.append({
                            'all_points_x': all_points_x,
                            'all_points_y': all_points_y
                        })
                        # Append the id into the num_ids list
                        num_ids.append(num_id)
                # If the ['object'] key only contains a dict value
                else:
                    # We just need to parse a single annotation
                    all_points_x, all_points_y, num_id = parse_single_annotation(bb_file['annotation']['object'])
                    # Append it into polygon and num_ids list
                    polygons.append({
                        'all_points_x': all_points_x,
                        'all_points_y': all_points_y
                    })
                    num_ids.append(num_id)
            # For this image, we need to create a dict to represent it and all the corresponding annotations represented by polygons and num_ids key list
            image_label = {
                'image_path': img_path,
                'image_id': curr_idx,
                'polygons': polygons,
                'num_ids': num_ids,
                'height': height,
                'width': width
            }
            curr_idx = curr_idx + 1
            # Append it into the images_list
            images_list.append(image_label)
    return images_list

# %% [markdown]
# # Store annotations into the respective train and test dataset

# %% [markdown]
# ## Load the training dataset and prepare

# %%
train_images = transform_annotations(os.path.join(train_image_path, 'train'))
print(train_images[0:5])
dataset_train = DetectorDataset()
dataset_train.load_labels(labels)
dataset_train.load_dataset(train_images)
dataset_train.prepare()
# Out:
# [{'image_path': '../../input/train_zip/train/apple_53.jpg', 'image_id': 100, 'polygons': [{'all_points_x': [45, 252, 252, 45, 45], 'all_points_y': [53, 53, 261, 261, 53]}], 'num_ids': [1], 'height': 261, 'width': 300}, {'image_path': '../../input/train_zip/train/orange_21.jpg', 'image_id': 101, 'polygons': [{'all_points_x': [607, 1030, 1030, 607, 607], 'all_points_y': [133, 133, 540, 540, 133]}, {'all_points_x': [1074, 1458, 1458, 1074, 1074], 'all_points_y': [230, 230, 657, 657, 230]}, {'all_points_x': [1018, 1498, 1498, 1018, 1018], 'all_points_y': [616, 616, 1048, 1048, 616]}], 'num_ids': [3, 3, 3], 'height': 1200, 'width': 1999}, {'image_path': '../../input/train_zip/train/banana_60.jpg', 'image_id': 102, 'polygons': [{'all_points_x': [11, 592, 592, 11, 11], 'all_points_y': [43, 43, 448, 448, 43]}, {'all_points_x': [24, 599, 599, 24, 24], 'all_points_y': [174, 174, 657, 657, 174]}], 'num_ids': [2, 2], 'height': 700, 'width': 900}, {'image_path': '../../input/train_zip/train/mixed_13.jpg', 'image_id': 103, 'polygons': [{'all_points_x': [138, 402, 402, 138, 138], 'all_points_y': [250, 250, 563, 563, 250]}, {'all_points_x': [129, 449, 449, 129, 129], 'all_points_y': [98, 98, 353, 353, 98]}, {'all_points_x': [204, 753, 753, 204, 204], 'all_points_y': [34, 34, 336, 336, 34]}], 'num_ids': [3, 1, 2], 'height': 600, 'width': 800}, {'image_path': '../../input/train_zip/train/apple_1.jpg', 'image_id': 104, 'polygons': [{'all_points_x': [8, 331, 331, 8, 8], 'all_points_y': [15, 15, 349, 349, 15]}], 'num_ids': [1], 'height': 349, 'width': 349}]

# %% [markdown]
# ## Load the test dataset and prepare

# %%
test_images = transform_annotations(os.path.join(test_image_path, 'test'))
dataset_val = DetectorDataset()
dataset_val.load_labels(labels)
dataset_val.load_dataset(test_images)
dataset_val.prepare()

# %% [markdown]
# ## Load and visualize the pixel mask for the first 5 objects

# %%
from mrcnn import visualize
for i in range(5):
    image_id = train_images[i]['image_id']
    mask, num_id = dataset_train.load_mask(i)
    img_data = cv2.imread(train_images[i]['image_path'])
    num_id = [x - 1 for x in num_id]
    visualize.display_top_masks(img_data, mask, num_id, labels)

# %% [markdown]
# # Start training

# %% [markdown]
# ## Download the coco weights

# %%
# !cd /kaggle && mkdir project
sys.path.append(ROOT_DIR)
MODEL_DIR = os.path.join(ROOT_DIR, 'logs')
# Local path to trained weights file
COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")
# Download COCO trained weights from Releases if needed
if not os.path.exists(COCO_MODEL_PATH):
    utils.download_trained_weights(COCO_MODEL_PATH)
# Out:
# Downloading pretrained model to /kaggle/project/mask_rcnn_coco.h5 ...
# ... done downloading pretrained model!

# %% [markdown]
# ## Create the model with the specified configuration defined at the top of the file

# %%
# Create model in training mode
model = modellib.MaskRCNN(mode="training", config=config,
                          model_dir=MODEL_DIR)

# %% [markdown]
# ## Load the weights of the COCO dataset

# %%
# Which weights to start with?
init_with = "coco"  # imagenet, coco, or last

if init_with == "imagenet":
    model.load_weights(model.get_imagenet_weights(), by_name=True)
elif init_with == "coco":
    # Load weights trained on MS COCO, but skip layers that
    # are different due to the different number of classes
    # See README for instructions to download the COCO weights
    model.load_weights(COCO_MODEL_PATH, by_name=True,
                       exclude=["mrcnn_class_logits", "mrcnn_bbox_fc", 
                                "mrcnn_bbox", "mrcnn_mask"])
elif init_with == "last":
    # Load the last model you trained and continue training
    model.load_weights(model.find_last(), by_name=True)

# %% [markdown]
# ## Now we can start training the actual dataset

# %%
# Train the head branches
# Passing layers="heads" freezes all layers except the head
# layers. You can also pass a regular expression to select
# which layers to train by name pattern.
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE, 
            epochs=30, 
            layers='heads')
# Out:
# Starting at epoch 0. LR=0.001
#
# Checkpoint Path: /kaggle/project/logs/fruits20190714T1502/mask_rcnn_fruits_{epoch:04d}.h5
# Selecting layers to train
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /opt/conda/lib/python3.6/site-packages/keras/engine/training_generator.py:47: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the`keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'
# Epoch 1/30
# 25/25 [==============================] - 147s 6s/step - loss: 2.8027 - rpn_class_loss: 0.0163 - rpn_bbox_loss: 0.5405 - mrcnn_class_loss: 0.6466 - mrcnn_bbox_loss: 0.7702 - mrcnn_mask_loss: 0.8293 - val_loss: 1.7744 - val_rpn_class_loss: 0.0141 - val_rpn_bbox_loss: 0.5377 - val_mrcnn_class_loss: 0.2296 - val_mrcnn_bbox_loss: 0.5164 - val_mrcnn_mask_loss: 0.4766
# Epoch 2/30
# 25/25 [==============================] - 70s 3s/step - loss: 1.6326 - rpn_class_loss: 0.0132 - rpn_bbox_loss: 0.5459 - mrcnn_class_loss: 0.2197 - mrcnn_bbox_loss: 0.4352 - mrcnn_mask_loss: 0.4185 - val_loss: 1.4490 - val_rpn_class_loss: 0.0116 - val_rpn_bbox_loss: 0.4228 - val_mrcnn_class_loss: 0.2137 - val_mrcnn_bbox_loss: 0.4466 - val_mrcnn_mask_loss: 0.3545
# Epoch 3/30
# 25/25 [==============================] - 50s 2s/step - loss: 1.3417 - rpn_class_loss: 0.0106 - rpn_bbox_loss: 0.4052 - mrcnn_class_loss: 0.2300 - mrcnn_bbox_loss: 0.3518 - mrcnn_mask_loss: 0.3441 - val_loss: 1.3686 - val_rpn_class_loss: 0.0113 - val_rpn_bbox_loss: 0.4396 - val_mrcnn_class_loss: 0.2041 - val_mrcnn_bbox_loss: 0.3757 - val_mrcnn_mask_loss: 0.3380
# Epoch 4/30
# 25/25 [==============================] - 106s 4s/step - loss: 1.1917 - rpn_class_loss: 0.0084 - rpn_bbox_loss: 0.3522 - mrcnn_class_loss: 0.2206 - mrcnn_bbox_loss: 0.2852 - mrcnn_mask_loss: 0.3252 - val_loss: 1.2998 - val_rpn_class_loss: 0.0103 - val_rpn_bbox_loss: 0.4166 - val_mrcnn_class_loss: 0.2318 - val_mrcnn_bbox_loss: 0.3133 - val_mrcnn_mask_loss: 0.3279
# Epoch 5/30
# 25/25 [==============================] - 83s 3s/step - loss: 1.1120 - rpn_class_loss: 0.0110 - rpn_bbox_loss: 0.3458 - mrcnn_class_loss: 0.2101 - mrcnn_bbox_loss: 0.2542 - mrcnn_mask_loss: 0.2909 - val_loss: 1.2068 - val_rpn_class_loss: 0.0100 - val_rpn_bbox_loss: 0.3682 - val_mrcnn_class_loss: 0.2270 - val_mrcnn_bbox_loss: 0.3115 - val_mrcnn_mask_loss: 0.2901
# Epoch 6/30
# 25/25 [==============================] - 85s 3s/step - loss: 1.0349 - rpn_class_loss: 0.0095 - rpn_bbox_loss: 0.2694 - mrcnn_class_loss: 0.2102 - mrcnn_bbox_loss: 0.2442 - mrcnn_mask_loss: 0.3016 - val_loss: 1.2301 - val_rpn_class_loss: 0.0103 - val_rpn_bbox_loss: 0.3722 - val_mrcnn_class_loss: 0.2634 - val_mrcnn_bbox_loss: 0.2874 - val_mrcnn_mask_loss: 0.2968
# Epoch 7/30
# 25/25 [==============================] - 86s 3s/step - loss: 1.0110 - rpn_class_loss: 0.0065 - rpn_bbox_loss: 0.2624 - mrcnn_class_loss: 0.2347 - mrcnn_bbox_loss: 0.2384 - mrcnn_mask_loss: 0.2690 - val_loss: 1.2822 - val_rpn_class_loss: 0.0093 - val_rpn_bbox_loss: 0.3907 - val_mrcnn_class_loss: 0.2631 - val_mrcnn_bbox_loss: 0.3168 - val_mrcnn_mask_loss: 0.3024
# Epoch 8/30
# 25/25 [==============================] - 78s 3s/step - loss: 1.0200 - rpn_class_loss: 0.0066 - rpn_bbox_loss: 0.2595 - mrcnn_class_loss: 0.2385 - mrcnn_bbox_loss: 0.2319 - mrcnn_mask_loss: 0.2834 - val_loss: 1.1675 - val_rpn_class_loss: 0.0086 - val_rpn_bbox_loss: 0.3534 - val_mrcnn_class_loss: 0.2673 - val_mrcnn_bbox_loss: 0.2647 - val_mrcnn_mask_loss: 0.2735
# Epoch 9/30
# 25/25 [==============================] - 88s 4s/step - loss: 0.9488 - rpn_class_loss: 0.0065 - rpn_bbox_loss: 0.2327 - mrcnn_class_loss: 0.2428 - mrcnn_bbox_loss: 0.1922 - mrcnn_mask_loss: 0.2747 - val_loss: 1.1769 - val_rpn_class_loss: 0.0081 - val_rpn_bbox_loss: 0.3676 - val_mrcnn_class_loss: 0.2583 - val_mrcnn_bbox_loss: 0.2639 - val_mrcnn_mask_loss: 0.2790
# Epoch 10/30
# 25/25 [==============================] - 80s 3s/step - loss: 0.9512 - rpn_class_loss: 0.0085 - rpn_bbox_loss: 0.2343 - mrcnn_class_loss: 0.2400 - mrcnn_bbox_loss: 0.1927 - mrcnn_mask_loss: 0.2756 - val_loss: 1.2615 - val_rpn_class_loss: 0.0087 - val_rpn_bbox_loss: 0.3874 - val_mrcnn_class_loss: 0.2630 - val_mrcnn_bbox_loss: 0.2878 - val_mrcnn_mask_loss: 0.3146
# Epoch 11/30
# 25/25 [==============================] - 79s 3s/step - loss: 0.8552 - rpn_class_loss: 0.0052 - rpn_bbox_loss: 0.2076 - mrcnn_class_loss: 0.1963 - mrcnn_bbox_loss: 0.1785 - mrcnn_mask_loss: 0.2676 - val_loss: 1.1623 - val_rpn_class_loss: 0.0083 - val_rpn_bbox_loss: 0.3631 - val_mrcnn_class_loss: 0.2597 - val_mrcnn_bbox_loss: 0.2519 - val_mrcnn_mask_loss: 0.2792
# Epoch 12/30
# 25/25 [==============================] - 83s 3s/step - loss: 0.9125 - rpn_class_loss: 0.0073 - rpn_bbox_loss: 0.2174 - mrcnn_class_loss: 0.2250 - mrcnn_bbox_loss: 0.1896 - mrcnn_mask_loss: 0.2732 - val_loss: 1.1262 - val_rpn_class_loss: 0.0080 - val_rpn_bbox_loss: 0.3185 - val_mrcnn_class_loss: 0.2794 - val_mrcnn_bbox_loss: 0.2553 - val_mrcnn_mask_loss: 0.2650
# Epoch 13/30
# 25/25 [==============================] - 82s 3s/step - loss: 0.7681 - rpn_class_loss: 0.0064 - rpn_bbox_loss: 0.1721 - mrcnn_class_loss: 0.1888 - mrcnn_bbox_loss: 0.1500 - mrcnn_mask_loss: 0.2507 - val_loss: 1.1465 - val_rpn_class_loss: 0.0086 - val_rpn_bbox_loss: 0.3135 - val_mrcnn_class_loss: 0.2788 - val_mrcnn_bbox_loss: 0.2885 - val_mrcnn_mask_loss: 0.2571
# Epoch 14/30
# 25/25 [==============================] - 86s 3s/step - loss: 0.8042 - rpn_class_loss: 0.0053 - rpn_bbox_loss: 0.1859 - mrcnn_class_loss: 0.1895 - mrcnn_bbox_loss: 0.1740 - mrcnn_mask_loss: 0.2495 - val_loss: 1.1334 - val_rpn_class_loss: 0.0084 - val_rpn_bbox_loss: 0.3452 - val_mrcnn_class_loss: 0.2701 - val_mrcnn_bbox_loss: 0.2563 - val_mrcnn_mask_loss: 0.2533
# Epoch 15/30
# 25/25 [==============================] - 80s 3s/step - loss: 0.8037 - rpn_class_loss: 0.0071 - rpn_bbox_loss: 0.1804 - mrcnn_class_loss: 0.2084 - mrcnn_bbox_loss: 0.1583 - mrcnn_mask_loss: 0.2495 - val_loss: 1.0988 - val_rpn_class_loss: 0.0079 - val_rpn_bbox_loss: 0.3244 - val_mrcnn_class_loss: 0.2581 - val_mrcnn_bbox_loss: 0.2512 - val_mrcnn_mask_loss: 0.2572
# Epoch 16/30
# 25/25 [==============================] - 83s 3s/step - loss: 0.7595 - rpn_class_loss: 0.0055 - rpn_bbox_loss: 0.1493 - mrcnn_class_loss: 0.1769 - mrcnn_bbox_loss: 0.1632 - mrcnn_mask_loss: 0.2646 - val_loss: 1.1129 - val_rpn_class_loss: 0.0076 - val_rpn_bbox_loss: 0.3280 - val_mrcnn_class_loss: 0.2729 - val_mrcnn_bbox_loss: 0.2558 - val_mrcnn_mask_loss: 0.2485
# Epoch 17/30
# 25/25 [==============================] - 81s 3s/step - loss: 0.8170 - rpn_class_loss: 0.0061 - rpn_bbox_loss: 0.1803 - mrcnn_class_loss: 0.2006 - mrcnn_bbox_loss: 0.1705 - mrcnn_mask_loss: 0.2595 - val_loss: 1.0965 - val_rpn_class_loss: 0.0076 - val_rpn_bbox_loss: 0.3268 - val_mrcnn_class_loss: 0.2548 - val_mrcnn_bbox_loss: 0.2444 - val_mrcnn_mask_loss: 0.2630
# Epoch 18/30
# 25/25 [==============================] - 79s 3s/step - loss: 0.6882 - rpn_class_loss: 0.0059 - rpn_bbox_loss: 0.1393 - mrcnn_class_loss: 0.1632 - mrcnn_bbox_loss: 0.1278 - mrcnn_mask_loss: 0.2520 - val_loss: 1.1283 - val_rpn_class_loss: 0.0082 - val_rpn_bbox_loss: 0.3536 - val_mrcnn_class_loss: 0.2607 - val_mrcnn_bbox_loss: 0.2490 - val_mrcnn_mask_loss: 0.2569
# Epoch 19/30
# 25/25 [==============================] - 86s 3s/step - loss: 0.7266 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.1725 - mrcnn_class_loss: 0.1793 - mrcnn_bbox_loss: 0.1228 - mrcnn_mask_loss: 0.2466 - val_loss: 1.1186 - val_rpn_class_loss: 0.0079 - val_rpn_bbox_loss: 0.3356 - val_mrcnn_class_loss: 0.2841 - val_mrcnn_bbox_loss: 0.2378 - val_mrcnn_mask_loss: 0.2532
# Epoch 20/30
# 25/25 [==============================] - 78s 3s/step - loss: 0.6859 - rpn_class_loss: 0.0062 - rpn_bbox_loss: 0.1429 - mrcnn_class_loss: 0.1614 - mrcnn_bbox_loss: 0.1146 - mrcnn_mask_loss: 0.2608 - val_loss: 1.1377 - val_rpn_class_loss: 0.0073 - val_rpn_bbox_loss: 0.3421 - val_mrcnn_class_loss: 0.2720 - val_mrcnn_bbox_loss: 0.2455 - val_mrcnn_mask_loss: 0.2707
# Epoch 21/30
# 25/25 [==============================] - 82s 3s/step - loss: 0.6448 - rpn_class_loss: 0.0046 - rpn_bbox_loss: 0.1423 - mrcnn_class_loss: 0.1572 - mrcnn_bbox_loss: 0.1012 - mrcnn_mask_loss: 0.2395 - val_loss: 1.0571 - val_rpn_class_loss: 0.0077 - val_rpn_bbox_loss: 0.3193 - val_mrcnn_class_loss: 0.2556 - val_mrcnn_bbox_loss: 0.2238 - val_mrcnn_mask_loss: 0.2506
# Epoch 22/30
# 25/25 [==============================] - 79s 3s/step - loss: 0.6050 - rpn_class_loss: 0.0052 - rpn_bbox_loss: 0.1148 - mrcnn_class_loss: 0.1455 - mrcnn_bbox_loss: 0.1014 - mrcnn_mask_loss: 0.2381 - val_loss: 1.1071 - val_rpn_class_loss: 0.0074 - val_rpn_bbox_loss: 0.3405 - val_mrcnn_class_loss: 0.2549 - val_mrcnn_bbox_loss: 0.2403 - val_mrcnn_mask_loss: 0.2641
# Epoch 23/30
# 25/25 [==============================] - 79s 3s/step - loss: 0.6015 - rpn_class_loss: 0.0052 - rpn_bbox_loss: 0.1151 - mrcnn_class_loss: 0.1445 - mrcnn_bbox_loss: 0.0969 - mrcnn_mask_loss: 0.2397 - val_loss: 1.0678 - val_rpn_class_loss: 0.0069 - val_rpn_bbox_loss: 0.3359 - val_mrcnn_class_loss: 0.2491 - val_mrcnn_bbox_loss: 0.2268 - val_mrcnn_mask_loss: 0.2491
# Epoch 24/30
# 25/25 [==============================] - 82s 3s/step - loss: 0.5838 - rpn_class_loss: 0.0052 - rpn_bbox_loss: 0.1231 - mrcnn_class_loss: 0.1257 - mrcnn_bbox_loss: 0.0939 - mrcnn_mask_loss: 0.2359 - val_loss: 1.1084 - val_rpn_class_loss: 0.0077 - val_rpn_bbox_loss: 0.3542 - val_mrcnn_class_loss: 0.2397 - val_mrcnn_bbox_loss: 0.2322 - val_mrcnn_mask_loss: 0.2746
# Epoch 25/30
# 25/25 [==============================] - 86s 3s/step - loss: 0.5448 - rpn_class_loss: 0.0053 - rpn_bbox_loss: 0.1071 - mrcnn_class_loss: 0.1142 - mrcnn_bbox_loss: 0.0845 - mrcnn_mask_loss: 0.2338 - val_loss: 1.1062 - val_rpn_class_loss: 0.0067 - val_rpn_bbox_loss: 0.3333 - val_mrcnn_class_loss: 0.2665 - val_mrcnn_bbox_loss: 0.2368 - val_mrcnn_mask_loss: 0.2629
# Epoch 26/30
# 25/25 [==============================] - 76s 3s/step - loss: 0.5348 - rpn_class_loss: 0.0041 - rpn_bbox_loss: 0.1017 - mrcnn_class_loss: 0.1189 - mrcnn_bbox_loss: 0.0781 - mrcnn_mask_loss: 0.2319 - val_loss: 1.0885 - val_rpn_class_loss: 0.0080 - val_rpn_bbox_loss: 0.3312 - val_mrcnn_class_loss: 0.2663 - val_mrcnn_bbox_loss: 0.2260 - val_mrcnn_mask_loss: 0.2570
# Epoch 27/30
# 25/25 [==============================] - 78s 3s/step - loss: 0.5211 - rpn_class_loss: 0.0044 - rpn_bbox_loss: 0.0981 - mrcnn_class_loss: 0.1136 - mrcnn_bbox_loss: 0.0785 - mrcnn_mask_loss: 0.2266 - val_loss: 1.1008 - val_rpn_class_loss: 0.0070 - val_rpn_bbox_loss: 0.3415 - val_mrcnn_class_loss: 0.2477 - val_mrcnn_bbox_loss: 0.2386 - val_mrcnn_mask_loss: 0.2659
# Epoch 28/30
# 25/25 [==============================] - 82s 3s/step - loss: 0.5200 - rpn_class_loss: 0.0047 - rpn_bbox_loss: 0.0945 - mrcnn_class_loss: 0.1179 - mrcnn_bbox_loss: 0.0728 - mrcnn_mask_loss: 0.2301 - val_loss: 1.0871 - val_rpn_class_loss: 0.0073 - val_rpn_bbox_loss: 0.3369 - val_mrcnn_class_loss: 0.2501 - val_mrcnn_bbox_loss: 0.2325 - val_mrcnn_mask_loss: 0.2602
# Epoch 29/30
# 25/25 [==============================] - 78s 3s/step - loss: 0.5626 - rpn_class_loss: 0.0045 - rpn_bbox_loss: 0.1097 - mrcnn_class_loss: 0.1108 - mrcnn_bbox_loss: 0.0837 - mrcnn_mask_loss: 0.2541 - val_loss: 1.1413 - val_rpn_class_loss: 0.0080 - val_rpn_bbox_loss: 0.3679 - val_mrcnn_class_loss: 0.2509 - val_mrcnn_bbox_loss: 0.2503 - val_mrcnn_mask_loss: 0.2642
# Epoch 30/30
# 25/25 [==============================] - 86s 3s/step - loss: 0.4826 - rpn_class_loss: 0.0034 - rpn_bbox_loss: 0.0845 - mrcnn_class_loss: 0.1086 - mrcnn_bbox_loss: 0.0639 - mrcnn_mask_loss: 0.2222 - val_loss: 1.1085 - val_rpn_class_loss: 0.0070 - val_rpn_bbox_loss: 0.3502 - val_mrcnn_class_loss: 0.2503 - val_mrcnn_bbox_loss: 0.2344 - val_mrcnn_mask_loss: 0.2666

# %% [markdown]
# # Visualize image output

# %%
os.listdir(MODEL_DIR)
# Out:
# ['fruits20190714T1502']

# %%
dir_names = os.listdir(MODEL_DIR)
dir_names = sorted(dir_names)

fps = []
# Pick last directory
for d in dir_names: 
    dir_name = os.path.join(MODEL_DIR, d)
    # Find the last checkpoint
    checkpoints = next(os.walk(dir_name))[2]
    checkpoints = filter(lambda f: f.startswith("mask_rcnn"), checkpoints)
    checkpoints = sorted(checkpoints)
    if not checkpoints:
        print('No weight files in {}'.format(dir_name))
    else: 
      
      checkpoint = os.path.join(dir_name, checkpoints[-1])
      fps.append(checkpoint)

model_path = sorted(fps)[-1]
print('Found model {}'.format(model_path))
# Out:
# Found model /kaggle/project/logs/fruits20190714T1502/mask_rcnn_fruits_0030.h5

# %% [markdown]
# # Create inference configuration

# %%
class InferenceConfig(DetectorConfig):
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

inference_config = InferenceConfig()

# Recreate the model in inference mode
model = modellib.MaskRCNN(mode='inference', 
                          config=inference_config,
                          model_dir=ROOT_DIR)

# Load trained weights (fill in path to trained weights here)
assert model_path != "", "Provide path to trained weights"
print("Loading weights from ", model_path)
model.load_weights(model_path, by_name=True)
# Out:
# Loading weights from  /kaggle/project/logs/fruits20190714T1502/mask_rcnn_fruits_0030.h5
# Re-starting from epoch 30

# %%
# set color for class
def get_colors_for_class_ids(class_ids):
    class_ids = [x - 1 for x in class_ids]
    colors = []
    for class_id in class_ids:
        if class_id == 1:
            colors.append((.941, .204, .204))
    return colors

# %% [markdown]
# # Predict output

# %%
# Show few example of ground truth vs. predictions on the validation dataset 
dataset = dataset_val
fig = plt.figure(figsize=(10, 30))
start_idx = 0
for i in range(start_idx, start_idx + 3):
    
    image_id = random.choice(dataset.image_ids)
    
    original_image, image_meta, gt_class_id, gt_bbox, gt_mask =\
        modellib.load_image_gt(dataset_val, inference_config, 
                               image_id, use_mini_mask=False)
    plt.subplot(6, 2, 2*(i-start_idx) + 1)
    visualize.display_instances(original_image, gt_bbox, gt_mask, gt_class_id, 
                                dataset.class_names,
                                colors=get_colors_for_class_ids(gt_class_id), ax=fig.axes[-1])
    
    plt.subplot(6, 2, 2*(i-start_idx) + 2)
    results = model.detect([original_image]) #, verbose=1)
    r = results[0]
    visualize.display_instances(original_image, r['rois'], r['masks'], r['class_ids'], 
                                dataset.class_names, r['scores'], 
                                colors=get_colors_for_class_ids(r['class_ids']), ax=fig.axes[-1])

# %%
# remove files to allow committing (hit files limit otherwise)
# !rm -rf /kaggle/working/Mask_RCNN
